# %%
import micropip
await micropip.install("../packages/py_banshee-1.1.1-py3-none-any.whl")
# Out:
# Collecting micropip
#   Using cached micropip-0.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=23.0 in c:\users\chari\miniconda3\envs\my_new_book_2\lib\site-packages (from micropip) (24.2)
# Using cached micropip-0.7.1-py3-none-any.whl (46 kB)
# Installing collected packages: micropip
# Successfully installed micropip-0.7.1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 get_ipython().system('pip install micropip')
#       2 import micropip
# ----> 3 await micropip.install("/packages/py_banshee-1.1.1-py3-none-any.whl")
#
# File c:\Users\chari\miniconda3\envs\my_new_book_2\Lib\site-packages\micropip\package_manager.py:133, in PackageManager.install(self, requirements, keep_going, deps, credentials, pre, index_urls, verbose)
#     130 if index_urls is None:
#     131     index_urls = self.index_urls
# --> 133 return await install(
#     134     requirements,
#     135     index_urls,
#     136     keep_going,
#     137     deps,
#     138     credentials,
#     139     pre,
#     140     verbose=verbose,
#     141 )
#
# File c:\Users\chari\miniconda3\envs\my_new_book_2\Lib\site-packages\micropip\install.py:53, in install(requirements, index_urls, keep_going, deps, credentials, pre, verbose)
#      41 wheel_base = Path(getsitepackages()[0])
#      43 transaction = Transaction(
#      44     ctx=ctx,  # type: ignore[arg-type]
#      45     ctx_extras=[],
#    (...)
#      51     index_urls=index_urls,
#      52 )
# ---> 53 await transaction.gather_requirements(requirements)
#      55 if transaction.failed:
#      56     failed_requirements = ", ".join([f"'{req}'" for req in transaction.failed])
#
# File c:\Users\chari\miniconda3\envs\my_new_book_2\Lib\site-packages\micropip\transaction.py:55, in Transaction.gather_requirements(self, requirements)
#      52 for requirement in requirements:
#      53     requirement_promises.append(self.add_requirement(requirement))
# ---> 55 await asyncio.gather(*requirement_promises)
#
# File c:\Users\chari\miniconda3\envs\my_new_book_2\Lib\site-packages\micropip\transaction.py:68, in Transaction.add_requirement(self, req)
#      65 wheel = WheelInfo.from_url(req)
#      66 check_compatible(wheel.filename)
# ---> 68 await self.add_wheel(wheel, extras=set(), specifier="")
#
# File c:\Users\chari\miniconda3\envs\my_new_book_2\Lib\site-packages\micropip\transaction.py:250, in Transaction.add_wheel(self, wheel, extras, specifier)
#     247 logger.info("Collecting %s%s", wheel.name, specifier)
#     248 logger.info("  Downloading %s", wheel.url.split("/")[-1])
# --> 250 await wheel.download(self.fetch_kwargs)
#     251 if self.deps:
#     252     await self.gather_requirements(wheel.requires(extras))
#
# File c:\Users\chari\miniconda3\envs\my_new_book_2\Lib\site-packages\micropip\wheelinfo.py:133, in WheelInfo.download(self, fetch_kwargs)
#     130 if self._data is not None:
#     131     return
# --> 133 self._data = await self._fetch_bytes(fetch_kwargs)
#     134 with zipfile.ZipFile(io.BytesIO(self._data)) as zf:
#     135     metadata_path = wheel_dist_info_dir(zf, self.name) + "/" + Metadata.PKG_INFO
#
# File c:\Users\chari\miniconda3\envs\my_new_book_2\Lib\site-packages\micropip\wheelinfo.py:154, in WheelInfo._fetch_bytes(self, fetch_kwargs)
#     151 async def _fetch_bytes(self, fetch_kwargs: dict[str, Any]):
#     152     if self.parsed_url.scheme not in ("https", "http", "emfs", "file"):
#     153         # Don't raise ValueError it gets swallowed
# --> 154         raise TypeError(
#     155             f"Cannot download from a non-remote location: {self.url!r} ({self.parsed_url!r})"
#     156         )
#     157     try:
#     158         bytes = await fetch_bytes(self.url, fetch_kwargs)
#
# TypeError: Cannot download from a non-remote location: 'file:////packages/py_banshee-1.1.1-py3-none-any.whl' (ParseResult(scheme='', netloc='', path='/packages/py_banshee-1.1.1-py3-none-any.whl', params='', query='', fragment=''))

# %% [markdown]
# # Bayesian Networks

# %%
from py_banshee.rankcorr import bn_rankcorr
# from py_banshee.bn_plot import bn_visualize
# from py_banshee.prediction import inference,conditional_margins_hist

#Defining the variables of the BN
names = ['V1','V2','V3']  #names of the variables (nodes)
N = len(names) 		      #number of nodes

#parametric distributions of the nodes
distributions = ['norm','genextreme','norm']	
parameters = [[100,23],[-0.15,130,50],[500,100]]

#Defining the structure of the BN
ParentCell = [None]*N
ParentCell[0] = []
ParentCell[1] = [0]
ParentCell[2] = [0,1]

#Defining the rank correlation matrix
RankCorr = [None]*N
RankCorr[0] = []
RankCorr[1] = [.1]
RankCorr[2] = [.41,-.25]

#Conditional rank correlation matrix
R = bn_rankcorr(ParentCell,RankCorr,var_names=names,is_data=False, plot=True)
